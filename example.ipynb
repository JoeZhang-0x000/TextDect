# %%
# !rm -rf ../imgs

# %%
# !mkdir ../imgs
# !mkdir ../imgs/frames
# !mkdir ../imgs/dect

# %%
# !python slice.py ../data/2008年美国总统选举相关视频.cnn.part2.wmv ../imgs/frames/

# %%
# !python detect.py ../imgs/frames ../imgs/dect 100
# Out:
# 共载入2042张图片
# 处理第0张...
# 处理../imgs/frames/frame_3015.jpg
# save ../imgs/dect/frame_3015.jpg
# 处理第1张...
# 处理../imgs/frames/frame_795.jpg
# save ../imgs/dect/frame_795.jpg
# 处理第2张...
# 处理../imgs/frames/frame_3870.jpg
# save ../imgs/dect/frame_3870.jpg
# 处理第3张...
# no text
# 处理第4张...
# 处理../imgs/frames/frame_19365.jpg
# save ../imgs/dect/frame_19365.jpg
# 处理第5张...
# no text
# 处理第6张...
# 处理../imgs/frames/frame_14850.jpg
# save ../imgs/dect/frame_14850.jpg
# 处理第7张...
# 处理../imgs/frames/frame_11685.jpg
# save ../imgs/dect/frame_11685.jpg
# 处理第8张...
# 处理../imgs/frames/frame_5670.jpg
# save ../imgs/dect/frame_5670.jpg
# 处理第9张...
# 处理../imgs/frames/frame_20100.jpg
# save ../imgs/dect/frame_20100.jpg
# 处理第10张...
# 处理../imgs/frames/frame_27450.jpg
# save ../imgs/dect/frame_27450.jpg
# 处理第11张...
# 处理../imgs/frames/frame_17775.jpg
# save ../imgs/dect/frame_17775.jpg
# 处理第12张...
# 处理../imgs/frames/frame_10440.jpg
# save ../imgs/dect/frame_10440.jpg
# 处理第13张...
# 处理../imgs/frames/frame_27465.jpg
# ...

# %%
import extract

# %%
extract.process('../imgs/dect/frame_2415_1.png')
# Out:
# MAX WIDTH:280, MAX HEIGHT:26
# 边界黑块数量:45，白块数量:567
# 背景偏亮，文字篇暗，翻转明暗度
# DAM COST:0.053519487380981445
# FLOOD FILL COST:8.344650268554688e-06
# 识别结果:WOULD GRANTING LEGAL STATUS TQ ILLEGAL
# IMPAIGRANTS AMOUNT TO AMNESTY?
# 'WOULD GRANTING LEGAL STATUS TQ ILLEGAL\nIMPAIGRANTS AMOUNT TO AMNESTY?\n'

# %%
extract.MAX_W = 10
extract.process('../imgs/dect/frame_2385_0.png')
# Out:
# MAX WIDTH:154, MAX HEIGHT:38
# 边界黑块数量:51，白块数量:333
# 背景偏亮，文字篇暗，翻转明暗度
# DAM COST:0.06566119194030762
# FLOOD FILL COST:0.0005109310150146484
# 识别结果:IR-T™
# DEMBCRATIC DERATE B¥
# 'IR-T™\nDEMBCRATIC DERATE B¥\n'

# %%
extract.process('../imgs/dect/frame_27465_2.png')
# Out:
# MAX WIDTH:230, MAX HEIGHT:26
# 边界黑块数量:12，白块数量:500
# 背景偏亮，文字篇暗，翻转明暗度
# DAM COST:0.04754281044006348
# FLOOD FILL COST:5.0067901611328125e-06
# 识别结果:WHAT WOULD YOU OO TU REDUCE
# RECORD-HIGH GASOLINE PRICES?
# 'WHAT WOULD YOU OO TU REDUCE\nRECORD-HIGH GASOLINE PRICES?\n'

# %%
extract.process('../imgs/dect/frame_3870_4.png')
# Out:
# MAX WIDTH:282, MAX HEIGHT:28
# 边界黑块数量:20，白块数量:600
# 背景偏亮，文字篇暗，翻转明暗度
# DAM COST:0.06014108657836914
# FLOOD FILL COST:8.58306884765625e-06
# 识别结果:IS BUILDING A 700-MILE FENCE ALONG THE
# MEXICAN BORDER RIGHT OR WRONG?
# 'IS BUILDING A 700-MILE FENCE ALONG THE\nMEXICAN BORDER RIGHT OR WRONG?\n'
